# %% [markdown]
# # Minimal OpenAI Smoke Test
#
# This notebook verifies that the project can load `OPENAI_API_KEY` from `.env`, create an OpenAI client, and make one simple Responses API call.

# %% [markdown]
# ## 1. Load Environment and Create OpenAI Client
#
# Load environment variables from the project `.env` file and create the shared OpenAI client used by later cells.

# %%
from dotenv import load_dotenv
from openai import OpenAI
import os

load_dotenv(".env")

if not os.getenv("OPENAI_API_KEY"):
    raise RuntimeError("OPENAI_API_KEY was not loaded. Check that .env is in the notebook's working directory.")

openai_client = OpenAI()

# %% [markdown]
# ## 2. Define a Small LLM Helper Function
#
# Wrap the Responses API call in a small function so prompts can be tested repeatedly.

# %%
def llm(prompt: str) -> str:
    response = openai_client.responses.create(
        model="gpt-5.4-mini",
        input=prompt,
    )
    return response.output_text

# %% [markdown]
# ## 3. Run a Simple Test Prompt
#
# Send one short prompt to confirm the API key, network, and model are working.

# %%
llm("Hey, what's up?")
